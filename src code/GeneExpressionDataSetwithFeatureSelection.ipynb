# %%
import pandas as pd
import numpy as np
import sklearn
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
from sklearn import preprocessing
import warnings

# %%
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv("finalDataSet.csv")

# %%
data.shape
# Out:
# (799, 16384)

# %%
le = preprocessing.LabelEncoder()#tTO CONVERT STRINGS TO NUMBERS AS WE CANNOT FORM DATASET USING STRINGS(PATENT ID,CLASS/)
pid = le.fit(data['Patient Id'])
pid = le.transform(data['Patient Id'])

# %%
res = le.fit(data['Class'])
res = le.transform(data['Class'])

# %%
data['Patient Id'] = pid
data['Class'] = res

# %%
data.isnull().values.any()
# Out:
# True

# %%
cnt=0#STRING
for i in data:
    for j in data[i]:
        if(type(j) == str):
            cnt+=1
        else:
            pass
print(cnt)
# Out:
# 2334

# %%
for i in data:
    try:
        data[i] = data[i].astype('float32')
    except:
        print(i)#NOT ABLE TO CONVERT TO FLOAT/INT
# Out:
# gene_1
# gene_2
# gene_3
# gene_6
# gene_11
# gene_12
# gene_19
# gene_29
# gene_1318
# gene_1329
# gene_1331
# gene_1334
# gene_1335
# gene_1445
# gene_1447
# gene_1449
# gene_1451
# gene_1455
# gene_1457
# gene_1461
# gene_1462
# gene_1464
# gene_3237
# gene_3244
# gene_3246
# gene_3248
# gene_3249
# gene_3251
# gene_3254
# gene_3256
# gene_3258
# gene_3318
# gene_3998
# gene_4003
# gene_5019
# gene_5020
# gene_5021
# gene_5027
# gene_5273
# gene_5274
# gene_5279
# gene_5281
# gene_5283
# gene_5285
# gene_5287
# gene_7239
# gene_7241
# gene_7242
# gene_7245
# gene_7249
# gene_7256
# gene_10593
# gene_10597
# gene_10598
# gene_10599
# gene_10600
# gene_10603
# gene_10604
# gene_10605
# gene_10606
# gene_10607
# gene_10608
# gene_10609
# gene_10610

# %%
ls=['gene_1',
'gene_2',
'gene_3',
'gene_6',
'gene_11',
'gene_12',
'gene_19',
'gene_29',
'gene_1318',
'gene_1329',
'gene_1331',
'gene_1334',
'gene_1335',
'gene_1445',
'gene_1447',
'gene_1449',
'gene_1451',
'gene_1455',
'gene_1457',
'gene_1461',
'gene_1462',
'gene_1464',
'gene_3237',
'gene_3244',
'gene_3246',
'gene_3248',
'gene_3249',
'gene_3251',
'gene_3254',
'gene_3256',
'gene_3258',
'gene_3318',
'gene_3998',
'gene_4003',
'gene_5019',
'gene_5020',
'gene_5021',
'gene_5027',
'gene_5273',
'gene_5274',
'gene_5279',
'gene_5281',
'gene_5283',
'gene_5285',
'gene_5287',
'gene_7239',
'gene_7241',
'gene_7242',
'gene_7245',
'gene_7249',
'gene_7256',
'gene_10593',
'gene_10597',
'gene_10598',
'gene_10599',
'gene_10600',
'gene_10603',
'gene_10604',
'gene_10605',
'gene_10606',
'gene_10607',
'gene_10608',
'gene_10609',
'gene_10610']

# %%
for i in ls:
    print(data[i].dtype)
    #data[i] = data[i].astype('float32')#THESE COLUMNS CONTAIN MULTIPLE TYPES(STRING,INT,FLOAT)
# Out:
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object

# %%
sym = ['!','@','#', '$', '^', '&', '*','.','?','<','>','.',";", "'",'"']#CHECKING FOR SPECIAL CHARACTERS
cnt = 0
for i in ls:
    for j in data[i]:
        try:
            if(j in sym or type(j) == str or j == '?'):
                try:
                    data[i] = data[i].replace({j: float(j)})#TRYING TO CONVERT TO FLOAT 
                except:
                    data[i] = data[i].replace({j: 'NaN'})#IF NOT,REPLACING THEM WITH NULL
                    cnt+=1
        except:
            pass

print(cnt)
# Out:
# 72

# %%
clm=[]
for i in data:
    clm.append(i)

# %%
for i in ls:
    print(data[i].dtype)
# Out:
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# object

# %%
X = data.drop('Class', axis = 1)
x = X
del x['Patient Id']
x
# Out:
#        gene_0    gene_1    gene_2     gene_3     gene_4  gene_5    gene_6  \
# 0    0.000000  2.017209  3.265527   5.478487  10.431999     0.0  7.175175
# 1    0.000000  0.592732  1.588421   7.586157   9.623011     0.0  6.816049
# 2    0.000000  3.511759  4.327199   6.881787   9.870730     0.0  6.972130
# 3    0.000000  3.663618  4.507649   6.659068  10.196184     0.0  7.843375
# 4    0.000000  2.655741  2.821547        NaN   9.738265     0.0  6.566967
# 5    0.000000  3.467853  3.581918   6.620243   9.706829     0.0  7.758510
# 6    0.000000  1.224966  1.691177   6.572007   9.640511     0.0  6.754888
# 7    0.000000  2.854853  1.750478   7.226720   9.758691     0.0  5.952103
# 8    0.000000  3.992125  2.772730   6.546692  10.488252     0.0       NaN
# 9    0.000000  3.642494  4.423558   6.849511   9.464466     0.0  7.947216
# 10   0.000000  3.492071  3.553373   7.151707  10.253446     0.0  8.301258
# 11   0.000000  2.941181  2.663276   6.516897   9.376292     0.0  7.860323
# ...

# %%
y = data['Class']
y
# Out:
# 0      4.0
# 1      3.0
# 2      4.0
# 3      4.0
# 4      0.0
# 5      4.0
# 6      2.0
# 7      4.0
# 8      0.0
# 9      4.0
# 10     0.0
# 11     2.0
# 12     4.0
# 13     0.0
# 14     0.0
# 15     0.0
# 16     3.0
# 17     2.0
# 18     2.0
# 19     4.0
# 20     0.0
# 21     2.0
# 22     3.0
# 23     0.0
# 24     2.0
# 25     3.0
# 26     1.0
# 27     0.0
# 28     0.0
# 29     0.0
#       ...
# 769    0.0
# 770    0.0
# 771    3.0
# 772    0.0
# 773    3.0
# 774    2.0
# 775    0.0
# 776    3.0
# 777    2.0
# 778    3.0
# 779    3.0
# 780    3.0
# 781    2.0
# 782    0.0
# 783    4.0
# 784    0.0
# 785    0.0
# 786    2.0
# 787    0.0
# 788    4.0
# 789    2.0
# 790    0.0
# 791    0.0
# 792    0.0
# 793    0.0
# 794    4.0
# 795    3.0
# 796    0.0
# 797    3.0
# 798    1.0
# Name: Class, Length: 799, dtype: float32

# %%
from sklearn.impute import SimpleImputer 
imputer = SimpleImputer(missing_values=np.nan, strategy='mean')
#from sklearn.preprocessing import Imputer
#imputer=Imputer(missing_values = np.nan,strategy='mean', axis=0,verbose=0)
imputer.fit(x)
x = imputer.transform(x)
x
# Out:
# array([[0.        , 2.01720929, 3.26552691, ..., 0.        , 9.29193306,
#         0.84092641],
#        [0.        , 0.5927321 , 1.58842082, ..., 1.59081757, 3.46740985,
#         1.17804527],
#        [0.        , 3.51175898, 4.32719872, ..., 0.        , 5.53370953,
#         0.22589186],
#        ...,
#        [0.        , 1.86564173, 2.71819721, ..., 0.49692246, 4.95514059,
#         3.21768045],
#        [0.        , 3.94295546, 4.45380727, ..., 7.07921791, 4.48480844,
#         5.78779793],
#        [0.        , 3.24958187, 3.70749166, ..., 6.82536602, 7.56745434,
#         2.47547412]])

# %%
np.savetxt("test_array1.csv",x,delimiter=",")

# %%
column_names=list(data.columns)[1:len(list(data.columns))-1]

# %%
test_df=pd.DataFrame(x,columns=column_names)

# %%
test_df
# Out:
#        gene_0    gene_1    gene_2     gene_3     gene_4  gene_5    gene_6  \
# 0    0.000000  2.017209  3.265527   5.478487  10.431999     0.0  7.175175
# 1    0.000000  0.592732  1.588421   7.586157   9.623011     0.0  6.816049
# 2    0.000000  3.511759  4.327199   6.881787   9.870730     0.0  6.972130
# 3    0.000000  3.663618  4.507649   6.659068  10.196184     0.0  7.843375
# 4    0.000000  2.655741  2.821547   6.744767   9.738265     0.0  6.566967
# 5    0.000000  3.467853  3.581918   6.620243   9.706829     0.0  7.758510
# 6    0.000000  1.224966  1.691177   6.572007   9.640511     0.0  6.754888
# 7    0.000000  2.854853  1.750478   7.226720   9.758691     0.0  5.952103
# 8    0.000000  3.992125  2.772730   6.546692  10.488252     0.0  7.403477
# 9    0.000000  3.642494  4.423558   6.849511   9.464466     0.0  7.947216
# 10   0.000000  3.492071  3.553373   7.151707  10.253446     0.0  8.301258
# 11   0.000000  2.941181  2.663276   6.516897   9.376292     0.0  7.860323
# ...

# %%
test_df.to_csv('dataset3.csv')

# %%
test_df
# Out:
#        gene_0    gene_1    gene_2     gene_3     gene_4  gene_5    gene_6  \
# 0    0.000000  2.017209  3.265527   5.478487  10.431999     0.0  7.175175
# 1    0.000000  0.592732  1.588421   7.586157   9.623011     0.0  6.816049
# 2    0.000000  3.511759  4.327199   6.881787   9.870730     0.0  6.972130
# 3    0.000000  3.663618  4.507649   6.659068  10.196184     0.0  7.843375
# 4    0.000000  2.655741  2.821547   6.744767   9.738265     0.0  6.566967
# 5    0.000000  3.467853  3.581918   6.620243   9.706829     0.0  7.758510
# 6    0.000000  1.224966  1.691177   6.572007   9.640511     0.0  6.754888
# 7    0.000000  2.854853  1.750478   7.226720   9.758691     0.0  5.952103
# 8    0.000000  3.992125  2.772730   6.546692  10.488252     0.0  7.403477
# 9    0.000000  3.642494  4.423558   6.849511   9.464466     0.0  7.947216
# 10   0.000000  3.492071  3.553373   7.151707  10.253446     0.0  8.301258
# 11   0.000000  2.941181  2.663276   6.516897   9.376292     0.0  7.860323
# ...

# %%
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_selection import SelectFromModel

# %%
from sklearn.model_selection import train_test_split 
X_train, X_test, y_train, y_test = train_test_split(test_df, y, test_size=0.25, random_state=42)

# %%
sel = SelectFromModel(RandomForestClassifier(n_estimators = 12000))
sel.fit(X_train, y_train)
# Out:
# SelectFromModel(estimator=RandomForestClassifier(n_estimators=12000))

# %%
sel.get_support()
# Out:
# array([False, False, False, ...,  True,  True, False])

# %%
selected_feat= X_train.columns[(sel.get_support())]
len(selected_feat)
# Out:
# 1721

# %%
print(selected_feat)
# Out:
# Index(['gene_18', 'gene_28', 'gene_29', 'gene_30', 'gene_39', 'gene_83',
#        'gene_88', 'gene_89', 'gene_91', 'gene_92',
#        ...
#        'gene_16348', 'gene_16350', 'gene_16354', 'gene_16358', 'gene_16361',
#        'gene_16363', 'gene_16372', 'gene_16377', 'gene_16379', 'gene_16380'],
#       dtype='object', length=1721)

# %%
import sys
import numpy as np
np.set_printoptions(threshold=np.inf)
print(selected_feat)
np.array(selected_feat)
# Out:
# Index(['gene_18', 'gene_28', 'gene_29', 'gene_30', 'gene_39', 'gene_83',
#        'gene_88', 'gene_89', 'gene_91', 'gene_92',
#        ...
#        'gene_16348', 'gene_16350', 'gene_16354', 'gene_16358', 'gene_16361',
#        'gene_16363', 'gene_16372', 'gene_16377', 'gene_16379', 'gene_16380'],
#       dtype='object', length=1721)
# array(['gene_18', 'gene_28', 'gene_29', 'gene_30', 'gene_39', 'gene_83',
#        'gene_88', 'gene_89', 'gene_91', 'gene_92', 'gene_122', 'gene_123',
#        'gene_131', 'gene_133', 'gene_134', 'gene_142', 'gene_145',
#        'gene_146', 'gene_148', 'gene_172', 'gene_177', 'gene_180',
#        'gene_184', 'gene_197', 'gene_203', 'gene_216', 'gene_218',
#        'gene_219', 'gene_220', 'gene_221', 'gene_223', 'gene_231',
#        'gene_233', 'gene_263', 'gene_271', 'gene_281', 'gene_297',
#        'gene_318', 'gene_333', 'gene_352', 'gene_354', 'gene_355',
#        'gene_357', 'gene_362', 'gene_365', 'gene_367', 'gene_371',
# ...

# %%
v=test_df.columns

# %%
d=test_df[['gene_18', 'gene_26', 'gene_30', 'gene_36', 'gene_83', 'gene_88',
       'gene_89', 'gene_91', 'gene_92', 'gene_122', 'gene_123',
       'gene_133', 'gene_134', 'gene_142', 'gene_145', 'gene_148',
       'gene_172', 'gene_180', 'gene_184', 'gene_197', 'gene_203',
       'gene_216', 'gene_218', 'gene_219', 'gene_220', 'gene_221',
       'gene_223', 'gene_231', 'gene_233', 'gene_263', 'gene_271',
       'gene_295', 'gene_297', 'gene_298', 'gene_318', 'gene_352',
       'gene_355', 'gene_357', 'gene_362', 'gene_365', 'gene_367',
       'gene_371', 'gene_374', 'gene_375', 'gene_380', 'gene_381',
       'gene_387', 'gene_399', 'gene_423', 'gene_425', 'gene_429',
       'gene_438', 'gene_439', 'gene_440', 'gene_445', 'gene_450',
       'gene_451', 'gene_454', 'gene_472', 'gene_487', 'gene_494',
       'gene_512', 'gene_521', 'gene_524', 'gene_532', 'gene_535',
       'gene_537', 'gene_538', 'gene_542', 'gene_544', 'gene_545',
       'gene_546', 'gene_550', 'gene_551', 'gene_553', 'gene_585',
       'gene_590', 'gene_592', 'gene_593', 'gene_594', 'gene_595',
       'gene_596', 'gene_609', 'gene_613', 'gene_616', 'gene_617',
       'gene_628', 'gene_638', 'gene_656', 'gene_660', 'gene_661',
       'gene_675', 'gene_706', 'gene_707', 'gene_722', 'gene_736',
       'gene_740', 'gene_742', 'gene_743', 'gene_747', 'gene_750',
       'gene_752', 'gene_753', 'gene_760', 'gene_763', 'gene_767',
       'gene_2634', 'gene_2638', 'gene_2639', 'gene_2667', 'gene_2695',
       'gene_2700', 'gene_2704', 'gene_2711', 'gene_2719', 'gene_2721',
       'gene_2725', 'gene_2728', 'gene_2738', 'gene_2747', 'gene_2762',
       'gene_2767', 'gene_2769', 'gene_2774', 'gene_2778', 'gene_2793',
       'gene_2806', 'gene_2811', 'gene_2822', 'gene_2831', 'gene_2835',
       'gene_2844', 'gene_2845', 'gene_2849', 'gene_2851', 'gene_2856',
       'gene_2885', 'gene_2890', 'gene_2909', 'gene_2910', 'gene_2918',
       'gene_2919', 'gene_2928', 'gene_2932', 'gene_2938', 'gene_2951',
       'gene_2954', 'gene_2955', 'gene_2967', 'gene_2968', 'gene_2978',
       'gene_2983', 'gene_2992', 'gene_2998', 'gene_2999', 'gene_3008',
       'gene_3010', 'gene_3020', 'gene_3027', 'gene_3070', 'gene_3071',
       'gene_3111', 'gene_3119', 'gene_3121', 'gene_3151', 'gene_3170',
       'gene_3216', 'gene_3217', 'gene_3219', 'gene_3222', 'gene_3225',
       'gene_3229', 'gene_3257', 'gene_3259', 'gene_3261', 'gene_3263',
       'gene_3343', 'gene_3360', 'gene_3369', 'gene_3385', 'gene_3398',
       'gene_3400', 'gene_3401', 'gene_3416', 'gene_3417', 'gene_3427',
       'gene_3428', 'gene_3430', 'gene_3431', 'gene_3434', 'gene_3437',
       'gene_3438', 'gene_3439', 'gene_3440', 'gene_3443', 'gene_3448',
       'gene_3449', 'gene_3450', 'gene_3453', 'gene_3457', 'gene_3458',
       'gene_3461', 'gene_3472', 'gene_3489', 'gene_3493', 'gene_3523',
       'gene_3524', 'gene_3535', 'gene_3538', 'gene_3539', 'gene_3540',
       'gene_3541', 'gene_3542', 'gene_3554', 'gene_3564', 'gene_3569',
       'gene_3586', 'gene_3604', 'gene_3619', 'gene_3628', 'gene_3630',
       'gene_3639', 'gene_3642', 'gene_3645', 'gene_3655', 'gene_3656',
       'gene_3691', 'gene_3695', 'gene_3720', 'gene_3730', 'gene_3737',
       'gene_3754', 'gene_3756', 'gene_3761', 'gene_3776', 'gene_3779',
       'gene_3785', 'gene_3797', 'gene_3803', 'gene_3809', 'gene_3813',
       'gene_3820', 'gene_3829', 'gene_3836', 'gene_3843', 'gene_3849',
       'gene_3860', 'gene_3861', 'gene_3862', 'gene_3884', 'gene_3888',
       'gene_3889', 'gene_3890', 'gene_3893', 'gene_3895', 'gene_3921',
       'gene_3924', 'gene_3925', 'gene_3931', 'gene_3934', 'gene_3953',
       'gene_3958', 'gene_3966', 'gene_3970', 'gene_3973', 'gene_3976',
       'gene_4031', 'gene_4046', 'gene_4051', 'gene_4057', 'gene_4058',
       'gene_4062', 'gene_4115', 'gene_4121', 'gene_4135', 'gene_4156',
       'gene_4164', 'gene_4170', 'gene_4172', 'gene_4178', 'gene_4180',
       'gene_4182', 'gene_4205', 'gene_4210', 'gene_4215', 'gene_4223',
       'gene_5752', 'gene_5762', 'gene_5764', 'gene_5765', 'gene_5774',
       'gene_5801', 'gene_5814', 'gene_5815', 'gene_5819', 'gene_5823',
       'gene_5825', 'gene_5827', 'gene_5829', 'gene_5830', 'gene_5856',
       'gene_5857', 'gene_5866', 'gene_5869', 'gene_5870', 'gene_5874',
       'gene_5918', 'gene_5925', 'gene_5934', 'gene_5936', 'gene_5937',
       'gene_5939', 'gene_5941', 'gene_5943', 'gene_5971', 'gene_5978',
       'gene_5985', 'gene_5988', 'gene_5998', 'gene_6013', 'gene_6030',
       'gene_6040', 'gene_6041', 'gene_6072', 'gene_6093', 'gene_6101',
       'gene_6104', 'gene_6136', 'gene_6156', 'gene_6160', 'gene_6164',
       'gene_6168', 'gene_6195', 'gene_6199', 'gene_6208', 'gene_6212',
       'gene_6215', 'gene_6226', 'gene_6257', 'gene_6263', 'gene_6265',
       'gene_6271', 'gene_6330', 'gene_6355', 'gene_6361', 'gene_6364',
       'gene_6369', 'gene_6380', 'gene_6386', 'gene_6407', 'gene_6410',
       'gene_6411', 'gene_6451', 'gene_6474', 'gene_6487', 'gene_6530',
       'gene_6537', 'gene_6543', 'gene_6546', 'gene_6556', 'gene_6557',
       'gene_6558', 'gene_6566', 'gene_6572', 'gene_6583', 'gene_6584',
       'gene_6585', 'gene_6593', 'gene_6594', 'gene_6595', 'gene_6611',
       'gene_6615', 'gene_6618', 'gene_6622', 'gene_6637', 'gene_6638',
       'gene_6651', 'gene_6660', 'gene_6662', 'gene_6664', 'gene_6673',
       'gene_6687', 'gene_6719', 'gene_6720', 'gene_6721', 'gene_6723',
       'gene_6733', 'gene_6734', 'gene_6747', 'gene_6748', 'gene_6760',
       'gene_6789', 'gene_6816', 'gene_6817', 'gene_6818', 'gene_6824',
       'gene_6828', 'gene_6830', 'gene_6833', 'gene_6836', 'gene_6837',
       'gene_6838', 'gene_6840', 'gene_6851', 'gene_6861', 'gene_6875',
       'gene_6876', 'gene_6879', 'gene_6884', 'gene_6890', 'gene_6925',
       'gene_6926', 'gene_6935', 'gene_6937', 'gene_6940', 'gene_6946',
       'gene_6952', 'gene_6976', 'gene_6984', 'gene_6985', 'gene_6986',
       'gene_6990', 'gene_6996', 'gene_6998', 'gene_7008', 'gene_7010',
       'gene_7019', 'gene_7026', 'gene_7031', 'gene_7036', 'gene_7040',
       'gene_7049', 'gene_7058', 'gene_7061', 'gene_7062', 'gene_7063',
       'gene_7066', 'gene_7073', 'gene_7079', 'gene_7106', 'gene_7113',
       'gene_7114', 'gene_7116', 'gene_7118', 'gene_7123', 'gene_7134',
       'gene_7176', 'gene_7178', 'gene_7216', 'gene_7234', 'gene_7238',
       'gene_7279', 'gene_7285', 'gene_7292', 'gene_7295', 'gene_7343',
       'gene_7346', 'gene_7350', 'gene_7363', 'gene_7370', 'gene_7378',
       'gene_7379', 'gene_7390', 'gene_7395', 'gene_7396', 'gene_7417',
       'gene_7420', 'gene_7421', 'gene_7433', 'gene_7435', 'gene_7436',
       'gene_11464', 'gene_11467', 'gene_11474', 'gene_11494',
       'gene_11508', 'gene_11514', 'gene_11540', 'gene_11550',
       'gene_11562', 'gene_11566', 'gene_11576', 'gene_11596',
       'gene_11601', 'gene_11652', 'gene_11657', 'gene_11670',
       'gene_11672', 'gene_11675', 'gene_11685', 'gene_11698',
       'gene_11700', 'gene_11713', 'gene_11758', 'gene_11772',
       'gene_11773', 'gene_11792', 'gene_11820', 'gene_11825',
       'gene_11854', 'gene_11871', 'gene_11877', 'gene_11888',
       'gene_11903', 'gene_11905', 'gene_11909', 'gene_11910',
       'gene_11916', 'gene_11918', 'gene_11920', 'gene_11965',
       'gene_11999', 'gene_12004', 'gene_12007', 'gene_12009',
       'gene_12013', 'gene_12015', 'gene_12018', 'gene_12029',
       'gene_12030', 'gene_12046', 'gene_12062', 'gene_12065',
       'gene_12068', 'gene_12069', 'gene_12073', 'gene_12078',
       'gene_12079', 'gene_12089', 'gene_12099', 'gene_12109',
       'gene_12113', 'gene_12120', 'gene_12123', 'gene_12159',
       'gene_12169', 'gene_12187', 'gene_12188', 'gene_12204',
       'gene_12210', 'gene_12211', 'gene_12214', 'gene_12224',
       'gene_12245', 'gene_12253', 'gene_12262', 'gene_12263',
       'gene_12271', 'gene_12290', 'gene_12299', 'gene_12308',
       'gene_12320', 'gene_12323', 'gene_12332', 'gene_12333',
       'gene_12346', 'gene_12567', 'gene_12568', 'gene_12604',
       'gene_12745', 'gene_12756', 'gene_12761', 'gene_12769',
       'gene_12800', 'gene_12801', 'gene_12807', 'gene_12808',
       'gene_12834', 'gene_12839', 'gene_12847', 'gene_12848',
       'gene_12881', 'gene_12886', 'gene_12893', 'gene_12911',
       'gene_12913', 'gene_12928', 'gene_12931', 'gene_12943',
       'gene_12946', 'gene_12954', 'gene_12962', 'gene_12977',
       'gene_12983', 'gene_12984', 'gene_12987', 'gene_12990',
       'gene_12992', 'gene_12995', 'gene_13004', 'gene_13074',
       'gene_13076', 'gene_13084', 'gene_13103', 'gene_13111',
       'gene_13126', 'gene_13144', 'gene_13147', 'gene_13149',
       'gene_13152', 'gene_13161', 'gene_13166', 'gene_13169',
       'gene_13178', 'gene_13190', 'gene_13200', 'gene_13202',
       'gene_13210', 'gene_13211', 'gene_13216', 'gene_13217',
       'gene_13218', 'gene_13223', 'gene_13224', 'gene_13247',
       'gene_13277', 'gene_13298', 'gene_13306', 'gene_13314',
       'gene_13324', 'gene_13346', 'gene_13355', 'gene_13358',
       'gene_13367', 'gene_13379', 'gene_13393', 'gene_13400',
       'gene_13405', 'gene_13419', 'gene_13421', 'gene_13436',
       'gene_13456', 'gene_13459', 'gene_13462', 'gene_13470',
       'gene_13475', 'gene_13478', 'gene_13480', 'gene_13489',
       'gene_13493', 'gene_13497', 'gene_13506', 'gene_13507',
       'gene_13510', 'gene_13511', 'gene_13513', 'gene_13516',
       'gene_13517', 'gene_13523', 'gene_13526', 'gene_13527',
       'gene_13528', 'gene_13538', 'gene_13544', 'gene_13547',
       'gene_15473', 'gene_15517', 'gene_15525', 'gene_15531',
       'gene_15577', 'gene_15583', 'gene_15586', 'gene_15589',
       'gene_15590', 'gene_15591', 'gene_15598', 'gene_15613',
       'gene_15615', 'gene_15617', 'gene_15620', 'gene_15626',
       'gene_15633', 'gene_15641', 'gene_15667', 'gene_15668',
       'gene_15679', 'gene_15681', 'gene_15688', 'gene_15709',
       'gene_15734', 'gene_15736', 'gene_15789', 'gene_15790',
       'gene_15792', 'gene_15793', 'gene_15795', 'gene_15800',
       'gene_15803', 'gene_15807', 'gene_15808', 'gene_15813',
       'gene_15818', 'gene_15826', 'gene_15843', 'gene_15863',
       'gene_15865', 'gene_15866', 'gene_15893', 'gene_15894',
       'gene_15895', 'gene_15896', 'gene_15897', 'gene_15898',
       'gene_15899', 'gene_15900', 'gene_15906', 'gene_15907',
       'gene_15912', 'gene_15918', 'gene_15927', 'gene_15936',
       'gene_15947', 'gene_15952', 'gene_15970', 'gene_15982',
       'gene_15983', 'gene_15987', 'gene_15989', 'gene_15992',
       'gene_15996', 'gene_15999', 'gene_16010', 'gene_16013',
       'gene_16036', 'gene_16043', 'gene_16044', 'gene_16058',
       'gene_16061', 'gene_16064', 'gene_16078', 'gene_16088',
       'gene_16097', 'gene_16105', 'gene_16110', 'gene_16113',
       'gene_16115', 'gene_16118', 'gene_16121', 'gene_16123',
       'gene_16124', 'gene_16126', 'gene_16130', 'gene_16131',
       'gene_16132', 'gene_16133', 'gene_16138', 'gene_16146',
       'gene_16152', 'gene_16155', 'gene_16156', 'gene_16162',
       'gene_16169', 'gene_16170', 'gene_16172', 'gene_16173',
       'gene_16174', 'gene_16179', 'gene_16201', 'gene_16221',
       'gene_16230', 'gene_16233', 'gene_16236', 'gene_16239',
       'gene_16245', 'gene_16246', 'gene_16249', 'gene_16250',
       'gene_16255', 'gene_16259', 'gene_16263', 'gene_16272',
       'gene_16283', 'gene_16303', 'gene_16305', 'gene_16307',
       'gene_16316', 'gene_16318', 'gene_16319', 'gene_16329',
       'gene_16332', 'gene_16337', 'gene_16338', 'gene_16342',
       'gene_16348', 'gene_16350', 'gene_16354', 'gene_16358',
       'gene_16361', 'gene_16363', 'gene_16372', 'gene_16377',
       'gene_16380']]

# %%
d
# Out:
#        gene_18    gene_26   gene_30   gene_36    gene_83    gene_88  \
# 0     0.591871   7.215116  0.000000  0.000000  10.796510   7.408398
# 1     0.000000   9.949812  0.000000  0.587845   2.176738  11.801558
# 2     1.683023   6.096650  0.000000  0.452595   2.785739   4.359676
# 3     1.267356   3.913761  0.000000  0.768587   9.634793   5.983377
# 4     0.889707   1.942120  0.000000  0.000000  10.337165   8.704509
# 5     0.894294   0.894294  4.936704  0.000000   6.931707   4.461993
# 6     9.466878   0.000000  0.000000  1.476796   1.224966  10.922777
# 7     0.000000   5.145527  0.000000  1.053042   5.716837   5.202790
# 8     0.635337   6.080374  0.000000  0.000000   0.352307   8.980962
# 9     0.000000   0.724214  0.000000  0.000000   8.162769   2.779890
# 10    1.651683   3.920036  0.000000  0.892818  11.120879   9.341510
# 11    8.732354   0.000000  7.596823  3.541255   0.754118  11.894197
# 12    0.000000   2.782912  5.315548  0.000000   6.440992   8.936697
# ...

# %%
from sklearn.model_selection import train_test_split 
X_trainSel, X_testSel, y_trainSel, y_testSel = train_test_split(d, y, test_size=0.25, random_state=42)

# %%
from sklearn.naive_bayes import GaussianNB 
gnb = GaussianNB() 
gnb.fit(X_trainSel, y_trainSel) 
y_pred = gnb.predict(X_testSel)

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(y_testSel, y_pred)
# Out:
# array([[81,  0,  0,  0,  0],
#        [ 0, 18,  0,  0,  0],
#        [ 0,  0, 28,  1,  0],
#        [ 0,  0,  0, 40,  0],
#        [ 0,  0,  0,  0, 32]])

# %%
from sklearn.metrics import accuracy_score 
print ("Accuracy NB: ", accuracy_score(y_testSel, y_pred))
# Out:
# Accuracy NB:  0.995

# %%
# Create Decision Tree classifer object
from sklearn.tree import DecisionTreeClassifier 
clf = DecisionTreeClassifier()

# Train Decision Tree Classifer
clf = clf.fit(X_trainSel,y_trainSel)

#Predict the response for test dataset
y_pred = clf.predict(X_testSel)

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(y_testSel, y_pred)
# Out:
# array([[78,  0,  0,  0,  3],
#        [ 0, 18,  0,  0,  0],
#        [ 0,  0, 29,  0,  0],
#        [ 0,  0,  0, 40,  0],
#        [ 0,  0,  0,  1, 31]])

# %%
from sklearn.metrics import accuracy_score 
print ("Accuracy decision: ", accuracy_score(y_testSel, y_pred))
# Out:
# Accuracy decision:  0.98

# %%
from sklearn.ensemble import RandomForestClassifier
clf=RandomForestClassifier(n_estimators=5)
clf.fit(X_trainSel,y_trainSel)
y_pred=clf.predict(X_testSel)

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[81,  0,  0,  0,  0],
#        [ 0, 18,  0,  0,  0],
#        [ 0,  0, 29,  0,  0],
#        [ 2,  0,  0, 38,  0],
#        [ 0,  0,  0,  0, 32]])

# %%
from sklearn.metrics import accuracy_score 
print ("Accuracy Random forest: ", accuracy_score(y_testSel, y_pred))
# Out:
# Accuracy Random forest:  0.99

# %%
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import classification_report, confusion_matrix, roc_curve, auc

# %%
learning_rates = [0.05, 0.1, 0.25, 0.5, 0.75, 1]
for learning_rate in learning_rates:
    gb = GradientBoostingClassifier(n_estimators=20, learning_rate = learning_rate, max_features=2, max_depth = 2, random_state = 0)
    gb.fit(X_trainSel, y_trainSel)
    print("Learning rate: ", learning_rate)
    print("Accuracy score (training): {0:.3f}".format(gb.score(X_trainSel, y_trainSel)))
    print("Accuracy score (validation): {0:.3f}".format(gb.score(X_testSel, y_testSel)))
    print()
# Out:
# Learning rate:  0.05
# Accuracy score (training): 0.988
# Accuracy score (validation): 0.985
#
# Learning rate:  0.1
# Accuracy score (training): 1.000
# Accuracy score (validation): 0.990
#
# Learning rate:  0.25
# Accuracy score (training): 1.000
# Accuracy score (validation): 0.995
#
# Learning rate:  0.5
# Accuracy score (training): 1.000
# Accuracy score (validation): 0.995
#
# Learning rate:  0.75
# Accuracy score (training): 1.000
# Accuracy score (validation): 0.995
#
# Learning rate:  1
# Accuracy score (training): 1.000
# Accuracy score (validation): 0.995

# %%
gb = GradientBoostingClassifier(n_estimators=30, learning_rate = 0.5, max_features=2, max_depth = 2, random_state = 0)
gb.fit(X_train, y_train)
predictions = gb.predict(X_test)

print("Confusion Matrix:")
print(confusion_matrix(y_test, predictions))
print()
print("Classification Report")
print(classification_report(y_test, predictions))
from sklearn.metrics import accuracy_score 
print ("Accuracy : ", accuracy_score(y_test, predictions))
# Out:
# Confusion Matrix:
# [[81  0  0  0  0]
#  [ 0 18  0  0  0]
#  [ 0  0 28  1  0]
#  [ 1  0  0 39  0]
#  [ 1  0  0  0 31]]
#
# Classification Report
#               precision    recall  f1-score   support
#
#          0.0       0.98      1.00      0.99        81
#          1.0       1.00      1.00      1.00        18
#          2.0       1.00      0.97      0.98        29
#          3.0       0.97      0.97      0.97        40
#          4.0       1.00      0.97      0.98        32
#
#     accuracy                           0.98       200
#    macro avg       0.99      0.98      0.99       200
# weighted avg       0.99      0.98      0.98       200
#
# Accuracy :  0.985
